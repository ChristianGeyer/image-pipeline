# %%
import cv2
import time
import numpy as np

def measure_capture_timing(requested_width, requested_height, camera_index=0):
    """
    Requests a resolution, captures 10 frames,
    returns (actual_width, actual_height, mean_dt_seconds, approx_fps)
    """

    cap = cv2.VideoCapture(camera_index, cv2.CAP_AVFOUNDATION)

    if not cap.isOpened():
        raise RuntimeError("Could not open camera.")

    # Request resolution
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, requested_width)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, requested_height)

    # Give camera time to settle
    time.sleep(0.5)

    timestamps = []
    frames_captured = 0

    while frames_captured < 10:
        ret, frame = cap.read()
        if not ret:
            continue

        timestamps.append(time.perf_counter())
        frames_captured += 1

    cap.release()

    # Compute time differences between consecutive frames
    diffs = np.diff(timestamps)

    mean_dt = float(np.mean(diffs))
    approx_fps = 1.0 / mean_dt if mean_dt > 0 else 0.0

    actual_height, actual_width = frame.shape[:2]

    return actual_width, actual_height, mean_dt, approx_fps

# %%
camera_res = [[4656, 3496], [4208, 3120], [2592, 1944], [1920, 1080]]


for res in camera_res:
    w, h, mean_dt, fps = measure_capture_timing(res[0], res[1])

    print(f"Actual resolution: {w} x {h}")
    print(f"Mean time between frames: {mean_dt:.4f} seconds")
    print(f"Approx FPS: {fps:.2f}")
# Out:
# Actual resolution: 4656 x 3496
# Mean time between frames: 0.0995 seconds
# Approx FPS: 10.05
# Actual resolution: 4208 x 3120
# Mean time between frames: 0.1001 seconds
# Approx FPS: 9.99
# Actual resolution: 2592 x 1944
# Mean time between frames: 0.0998 seconds
# Approx FPS: 10.02
# Actual resolution: 1920 x 1080
# Mean time between frames: 0.0329 seconds
# Approx FPS: 30.41

# %%
import time

def current_timestamp_ms():
    t = time.time()
    lt = time.localtime(t)
    ms = int((t - int(t)) * 1000)
    return time.strftime("%Y%m%d_%H%M%S", lt) + f"_{ms:03d}"

print(current_timestamp_ms())
print(f"{time.time():.3f}")
# Out:
# 20260225_142534_389
# 1772029534.390
